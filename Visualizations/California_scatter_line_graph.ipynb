# %%
# Import Numpy for calculations and matplotlib for charting
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
from scipy import stats

# %%
# Read our data file the pandas library
file_path = Path("../Predictions/California_predictions_results.csv")
data = pd.read_csv(file_path)

file_path2 = Path("../Data/proj_4_feat_target_var_set.csv")
data2 = pd.read_csv(file_path2)

# Display sample data

data2
# Out:
#      fips_code state_id     state_name  high_tourist_border_sales  year  \
# 0            1       AL        Alabama                          0  2010
# 1            2       AK         Alaska                          1  2010
# 2            4       AZ        Arizona                          0  2010
# 3            5       AR       Arkansas                          0  2010
# 4            6       CA     California                          0  2010
# ..         ...      ...            ...                        ...   ...
# 607         51       VA       Virginia                          0  2021
# 608         53       WA     Washington                          0  2021
# 609         54       WV  West Virginia                          0  2021
# 610         55       WI      Wisconsin                          0  2021
# 611         56       WY        Wyoming                          0  2021
#
#      niaaa_pop_21_plus  census_total_pop  census_total_pop_21_plus  \
# 0              3439923           4785298                   3426273
# 1               494781            713985                    494078
# 2              4496526           6413737                   4502443
# 3              2082760           2921606                   2074340
# 4             26311028          37349363                  26293952
# ..                 ...               ...                       ...
# 607            6412892           8642274                   6395283
# 608            5795889           7738692                   5788542
# 609            1358876           1782959                   1351483
# 610            4383656           5895908                   4380660
# 611             424305            578803                    425420
#
#      census_percent_pop_21_plus  census_percent_pop_18_24  ...  \
# 0                         0.716                     0.102  ...
# 1                         0.692                     0.105  ...
# 2                         0.702                     0.099  ...
# 3                         0.710                     0.100  ...
# 4                         0.704                     0.106  ...
# ..                          ...                       ...  ...
# 607                       0.740                     0.095  ...
# 608                       0.748                     0.086  ...
# 609                       0.758                     0.088  ...
# 610                       0.743                     0.092  ...
# 611                       0.735                     0.090  ...
#
#      bea_personal_income_dollars  bea_disp_inc_dollars  \
# 0                       162068.8              148862.1
# 1                        35374.3               32703.9
# 2                       216223.6              198815.2
# 3                        94127.0               86387.0
# 4                      1609997.5             1431825.6
# ..                           ...                   ...
# 607                     578639.7              499639.6
# 608                     574266.8              505590.1
# 609                      87617.4               79840.2
# 610                     355048.0              314662.1
# 611                      40866.6               35940.5
#
#      bea_percapita_personal_income_dollars  bea_percapita_disp_inc_dollars  \
# 0                                    33849                           31091
# 1                                    49543                           45803
# 2                                    33774                           31055
# 3                                    32218                           29569
# 4                                    43138                           38364
# ..                                     ...                             ...
# 607                                  66838                           57713
# 608                                  74188                           65315
# 609                                  49071                           44715
# 610                                  60381                           53513
# 611                                  70522                           62022
#
#      census_median_household_inc_dollars  census_percent_pop_in_poverty_est  \
# 0                                  40474                              0.172
# 1                                  64576                              0.125
# 2                                  46789                              0.188
# 3                                  38307                              0.153
# 4                                  57708                              0.163
# ..                                   ...                                ...
# 607                                80963                              0.098
# 608                                84247                              0.077
# 609                                51248                              0.169
# 610                                67125                              0.093
# 611                                65204                              0.094
#
#      niaaa_total_beer_vol_consumed_gallons  \
# 0                                101835000
# 1                                 15476350
# 2                                140015325
# 3                                 53429000
# 4                                651673303
# ..                                     ...
# 607                              151097751
# 608                              125364000
# 609                               38037000
# 610                              135005000
# 611                               13053187
#
#      niaaa_legal_adult_per_capita_beer_consumed_gallons  \
# 0                                                29.60
# 1                                                31.28
# 2                                                31.14
# 3                                                25.65
# 4                                                24.77
# ..                                                 ...
# 607                                              23.56
# 608                                              21.63
# 609                                              27.99
# 610                                              30.80
# 611                                              30.76
#
#      ba_craft_beer_produced_gallons  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 607                      14074350.0
# 608                      17599728.0
# 609                        733894.0
# 610                      30531485.0
# 611                       2001329.0
#
#      ba_legal_adult_per_capita_craft_beer_produced_gallons
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 607                                               2.19
# 608                                               3.04
# 609                                               0.54
# 610                                               6.96
# 611                                               4.72
#
# [612 rows x 43 columns]

# %%
fips = 6
condition = data2['fips_code'] == fips
data2 = data2[condition]
data2
# Out:
#      fips_code state_id  state_name  high_tourist_border_sales  year  \
# 4            6       CA  California                          0  2010
# 55           6       CA  California                          0  2011
# 106          6       CA  California                          0  2012
# 157          6       CA  California                          0  2013
# 208          6       CA  California                          0  2014
# 259          6       CA  California                          0  2015
# 310          6       CA  California                          0  2016
# 361          6       CA  California                          0  2017
# 412          6       CA  California                          0  2018
# 463          6       CA  California                          0  2019
# 514          6       CA  California                          0  2020
# 565          6       CA  California                          0  2021
#
#      niaaa_pop_21_plus  census_total_pop  census_total_pop_21_plus  \
# 4             26311028          37349363                  26293952
# 55            26698281          37691912                  26685874
# 106           27093829          38041430                  27085498
# 157           27467761          38332521                  27446085
# 208           27843765          38802500                  27976603
# 259           28200824          39144818                  28379993
# 310           28500684          39250017                  28534762
# 361           28745762          39536653                  28861757
# 412           28923058          39557045                  28955757
# 463           29023260          39512223                  29041484
# 514           29029153          39368078                  28830884
# 565           28942489          39237836                  28918285
#
#      census_percent_pop_21_plus  census_percent_pop_18_24  ...  \
# 4                        0.7040                    0.1060  ...
# 55                       0.7080                    0.1060  ...
# 106                      0.7120                    0.1060  ...
# 157                      0.7160                    0.1050  ...
# 208                      0.7210                    0.1030  ...
# 259                      0.7250                    0.1010  ...
# 310                      0.7270                    0.0980  ...
# 361                      0.7300                    0.0960  ...
# 412                      0.7320                    0.0950  ...
# 463                      0.7350                    0.0930  ...
# 514                      0.7323                    0.0914  ...
# 565                      0.7370                    0.0910  ...
#
#      bea_personal_income_dollars  bea_disp_inc_dollars  \
# 4                      1609997.5             1431825.6
# 55                     1713428.0             1504645.4
# 106                    1814763.0             1590509.7
# 157                    1840885.3             1587112.7
# 208                    1955718.0             1679406.9
# 259                    2097049.6             1786764.4
# 310                    2191138.0             1871763.1
# 361                    2295048.7             1961488.7
# 412                    2411055.1             2057748.6
# 463                    2537950.6             2169277.3
# 514                    2767521.4             2368785.6
# 565                    3013676.9             2520230.0
#
#      bea_percapita_personal_income_dollars  bea_percapita_disp_inc_dollars  \
# 4                                    43138                           38364
# 55                                   45509                           39963
# 106                                  47794                           41888
# 157                                  48076                           41448
# 208                                  50619                           43467
# 259                                  53817                           45854
# 310                                  55863                           47721
# 361                                  58214                           49754
# 412                                  60984                           52048
# 463                                  64174                           54852
# 514                                  70061                           59967
# 565                                  76991                           64385
#
#      census_median_household_inc_dollars  census_percent_pop_in_poverty_est  \
# 4                                  57708                              0.163
# 55                                 57287                              0.169
# 106                                58328                              0.159
# 157                                60190                              0.149
# 208                                61933                              0.158
# 259                                64500                              0.139
# 310                                67739                              0.139
# 361                                71805                              0.124
# 412                                75277                              0.119
# 463                                80440                              0.101
# 514                                83056                              0.111
# 565                                84907                              0.119
#
#      niaaa_total_beer_vol_consumed_gallons  \
# 4                                651673303
# 55                               643901979
# 106                              676306044
# 157                              680648643
# 208                              699849640
# 259                              705526842
# 310                              687240437
# 361                              679722660
# 412                              743101000
# 463                              759376000
# 514                              771652000
# 565                              795212000
#
#      niaaa_legal_adult_per_capita_beer_consumed_gallons  \
# 4                                                24.77
# 55                                               24.12
# 106                                              24.96
# 157                                              24.78
# 208                                              25.13
# 259                                              25.02
# 310                                              24.11
# 361                                              23.65
# 412                                              25.69
# 463                                              26.16
# 514                                              26.58
# 565                                              27.48
#
#      ba_craft_beer_produced_gallons  \
# 4                               NaN
# 55                       62627626.0
# 106                      76067583.0
# 157                      91415740.0
# 208                     106116840.0
# 259                     117793335.0
# 310                     102151866.0
# 361                     101851274.0
# 412                     107793720.0
# 463                     117350416.0
# 514                     101140974.0
# 565                     110474426.0
#
#      ba_legal_adult_per_capita_craft_beer_produced_gallons
# 4                                                  NaN
# 55                                                2.35
# 106                                               2.81
# 157                                               3.33
# 208                                               3.81
# 259                                               4.18
# 310                                               3.58
# 361                                               3.54
# 412                                               3.73
# 463                                               4.04
# 514                                               3.48
# 565                                               3.82
#
# [12 rows x 43 columns]

# %%
sample_data = data['Predicted_Value']

# Calculate sample statistics
sample_mean = sample_data.mean()
sample_std = sample_data.std()
sample_size = len(sample_data)

# Choose confidence level
confidence_level = 0.95

# Calculate critical value
critical_value = stats.t.ppf((1 + confidence_level) / 2, df=sample_size - 1)

# Calulate standard error
standard_error = sample_std / (sample_size ** 0.5)

# Calculate margin of error
margin_of_error = critical_value * standard_error

# Calculate lower and upper bounds
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Add lower and upper bounds to a new column in the DataFrame

data['Lower Bound'] = lower_bound
data['Upper Bound'] = upper_bound

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
data.head()
# Out:
# Lower Bound: 25.364643660375677
# Upper Bound: 25.61307041557987
#    Percentage  Predicted_Value  Lower Bound  Upper Bound
# 0        0.01        25.151434    25.364644     25.61307
# 1        0.02        25.151434    25.364644     25.61307
# 2        0.03        25.151434    25.364644     25.61307
# 3        0.04        25.151434    25.364644     25.61307
# 4        0.05        25.256412    25.364644     25.61307

# %%
# Extract columns for X-axis, Y-axis, and error range bounds
x_values = data['Percentage']  # Replace 'X-axis' with the actual column name for X-axis data
y_values = data['Predicted_Value']  # Replace 'Y-axis' with the actual column name for Y-axis data

tolerance = 0.05
lowerY = data['Predicted_Value'] * (1 - tolerance)
upperY = data['Predicted_Value'] * (1 + tolerance)

# Plot the error range with the line graph
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='Predictions', color = 'darkblue')
plt.plot(x_values, lowerY, label='Lower bound', color = 'lightblue')
plt.plot(x_values, upperY, label='Upper bound', color = 'lightblue')
plt.fill_between(x_values, lowerY, upperY, color='gray', alpha=0.3, label=f'{tolerance*100}% Error Tolerance')

scatterX = data2['census_percent_pop_never_married']
scatterY = data2['niaaa_legal_adult_per_capita_beer_consumed_gallons']

plt.scatter(scatterX, scatterY, label='Scatterp plot', color='red')

# Customize labels and title
plt.xlabel('Percent Unmarried')
plt.ylabel('Per Capita Consumption')
plt.title('Scatter Plot with Error Range Line Chart')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
